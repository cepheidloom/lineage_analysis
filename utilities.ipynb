# %% [markdown]
# ##### SCRIPT 1:- SQL SCRIPT TO CREATE OBJECT DEFINTIONS RESULT SET
#
# ```sql
# --SQL SCRIPT TO CREATE OBJECT DEFINTIONS RESULT SET
#
# SELECT
# DatabaseName = DB_NAME(),
#     OBJECT_SCHEMA_NAME(m.object_id) AS [Schema],
#     OBJECT_NAME(m.object_id) AS [Object],
#     o.type_desc AS ObjectType,
#     REPLACE(REPLACE(m.definition, CHAR(13) + CHAR(10), '\n'), CHAR(9), '\t') AS definition
# FROM sys.sql_modules m
# JOIN sys.objects o
#     ON m.object_id = o.object_id;
# --
# ```
#
# ##### SCRIPT 2:- SQL SCRIPT TO CREATE DEPENCENCY RESULT SET
#
# ```sql
# --SQL SCRIPT TO CREATE DEPENCENCY RESULT SET
# SELECT
#     DB_NAME() AS [Database],
#     d.referencing_id                              AS [Dependent_Object_ID],
#     OBJECT_SCHEMA_NAME(d.referencing_id)          AS [Dependent_Schema],
#     OBJECT_NAME(d.referencing_id)                 AS [Dependent_Object_Name],
#     o1.type_desc                                  AS [Dependent_Object_Type],
#
#     -- Prefer name-based info to avoid losing unresolved refs; include resolved ID when available
#     d.referenced_id                               AS [Depends_On_Object_ID],
#     COALESCE(d.referenced_schema_name, OBJECT_SCHEMA_NAME(d.referenced_id)) AS [Depends_On_Schema],
#     COALESCE(d.referenced_entity_name,  OBJECT_NAME(d.referenced_id))       AS [Depends_On_Object_Name],
#
#     -- Type desc: resolved object type, or SYNONYM when matched in sys.synonyms, else NULL
#     COALESCE(
#         o2.type_desc,
#         CASE
#             WHEN syn_by_id.object_id IS NOT NULL              THEN 'SYNONYM'
#             WHEN syn_by_name.name IS NOT NULL                 THEN 'SYNONYM'
#         END
#     )                                              AS [Depends_On_Object_Type],
#
#     CONCAT(
#         '/',
#         COALESCE(d.referenced_schema_name, OBJECT_SCHEMA_NAME(d.referenced_id)), '.',
#         COALESCE(d.referenced_entity_name,  OBJECT_NAME(d.referenced_id)),
#         '/',
#         OBJECT_SCHEMA_NAME(d.referencing_id), '.', OBJECT_NAME(d.referencing_id)
#     )                                              AS [Object_Hierarchy]
#
# FROM sys.sql_expression_dependencies AS d
# INNER JOIN sys.objects AS o1
#     ON d.referencing_id = o1.object_id
#
# -- Keep referenced side as LEFT JOIN so unresolved references are still returned
# LEFT JOIN sys.objects  AS o2
#     ON d.referenced_id = o2.object_id
#
# -- Surface synonyms whether referenced_id resolves or only names are present
# LEFT JOIN sys.synonyms AS syn_by_id
#     ON syn_by_id.object_id = d.referenced_id
# LEFT JOIN sys.synonyms AS syn_by_name
#     ON syn_by_name.name = d.referenced_entity_name
#    AND SCHEMA_NAME(syn_by_name.schema_id) = d.referenced_schema_name
# ORDER BY
#     [Dependent_Object_Name],
#     [Depends_On_Object_Name];
# ```
#
#
# ##### SCRIPT 3:- Script 2 but also includes triggers and functions and other things.
#
# ```sql
# -- ENHANCED SQL SCRIPT: Include triggers and functions in dependency analysis
# SELECT
#     DB_NAME() AS [Database],
#     d.referencing_id                              AS [Dependent_Object_ID],
#     OBJECT_SCHEMA_NAME(d.referencing_id)          AS [Dependent_Schema],
#     OBJECT_NAME(d.referencing_id)                 AS [Dependent_Object_Name],
#     o1.type_desc                                  AS [Dependent_Object_Type],
#
#     -- Prefer name-based info to avoid losing unresolved refs; include resolved ID when available
#     d.referenced_id                               AS [Depends_On_Object_ID],
#     COALESCE(d.referenced_schema_name, OBJECT_SCHEMA_NAME(d.referenced_id)) AS [Depends_On_Schema],
#     COALESCE(d.referenced_entity_name,  OBJECT_NAME(d.referenced_id))       AS [Depends_On_Object_Name],
#
#     -- Type desc: resolved object type, or SYNONYM when matched in sys.synonyms, else NULL
#     COALESCE(
#         o2.type_desc,
#         CASE
#             WHEN syn_by_id.object_id IS NOT NULL              THEN 'SYNONYM'
#             WHEN syn_by_name.name IS NOT NULL                 THEN 'SYNONYM'
#         END
#     )                                              AS [Depends_On_Object_Type],
#
#     CONCAT(
#         '/',
#         COALESCE(d.referenced_schema_name, OBJECT_SCHEMA_NAME(d.referenced_id)), '.',
#         COALESCE(d.referenced_entity_name,  OBJECT_NAME(d.referenced_id)),
#         '/',
#         OBJECT_SCHEMA_NAME(d.referencing_id), '.', OBJECT_NAME(d.referencing_id)
#     )                                              AS [Object_Hierarchy]
#
# FROM sys.sql_expression_dependencies AS d
# INNER JOIN sys.objects AS o1
#     ON d.referencing_id = o1.object_id
#
# -- Keep referenced side as LEFT JOIN so unresolved references are still returned
# LEFT JOIN sys.objects  AS o2
#     ON d.referenced_id = o2.object_id
#
# -- Surface synonyms whether referenced_id resolves or only names are present
# LEFT JOIN sys.synonyms AS syn_by_id
#     ON syn_by_id.object_id = d.referenced_id
# LEFT JOIN sys.synonyms AS syn_by_name
#     ON syn_by_name.name = d.referenced_entity_name
#    AND SCHEMA_NAME(syn_by_name.schema_id) = d.referenced_schema_name
#
# WHERE
#     -- Include all object types (views, SPs, functions, triggers, etc.)
#     o1.type_desc IN (
#         'VIEW',
#         'SQL_STORED_PROCEDURE',
#         'SQL_SCALAR_FUNCTION',
#         'SQL_INLINE_TABLE_VALUED_FUNCTION',
#         'SQL_TABLE_VALUED_FUNCTION',
#         'CLR_SCALAR_FUNCTION',
#         'CLR_TABLE_VALUED_FUNCTION',
#         'SQL_TRIGGER',
#         'CLR_TRIGGER',
#         'USER_TABLE'  -- Tables can have computed columns that reference other objects
#     )
#
# ORDER BY
#     [Dependent_Object_Name],
#     [Depends_On_Object_Name];
# ```
#
#
# ##### SCRIPT 4:- SQL SCRIPT TO IDENTIFY STATIC SQL TABLES
# ```sql
# -- ENHANCED SQL SCRIPT: Identify all tables and their dependency status
# WITH all_tables AS (
#     -- Get all user tables in the database
#     SELECT
#         OBJECT_SCHEMA_NAME(object_id) AS schema_name,
#         name AS table_name,
#         object_id
#     FROM sys.tables
#     WHERE is_ms_shipped = 0  -- Exclude system tables
# ),
# dependency_info AS (
#     SELECT
#         DB_NAME() AS [Database],
#         d.referencing_id                              AS [Dependent_Object_ID],
#         OBJECT_SCHEMA_NAME(d.referencing_id)          AS [Dependent_Schema],
#         OBJECT_NAME(d.referencing_id)                 AS [Dependent_Object_Name],
#         o1.type_desc                                  AS [Dependent_Object_Type],
#
#         d.referenced_id                               AS [Depends_On_Object_ID],
#         COALESCE(d.referenced_schema_name, OBJECT_SCHEMA_NAME(d.referenced_id)) AS [Depends_On_Schema],
#         COALESCE(d.referenced_entity_name,  OBJECT_NAME(d.referenced_id))       AS [Depends_On_Object_Name],
#
#         COALESCE(
#             o2.type_desc,
#             CASE
#                 WHEN syn_by_id.object_id IS NOT NULL              THEN 'SYNONYM'
#                 WHEN syn_by_name.name IS NOT NULL                 THEN 'SYNONYM'
#             END
#         )                                              AS [Depends_On_Object_Type],
#
#         CONCAT(
#             '/',
#             COALESCE(d.referenced_schema_name, OBJECT_SCHEMA_NAME(d.referenced_id)), '.',
#             COALESCE(d.referenced_entity_name,  OBJECT_NAME(d.referenced_id)),
#             '/',
#             OBJECT_SCHEMA_NAME(d.referencing_id), '.', OBJECT_NAME(d.referencing_id)
#         )                                              AS [Object_Hierarchy]
#
#     FROM sys.sql_expression_dependencies AS d
#     INNER JOIN sys.objects AS o1
#         ON d.referencing_id = o1.object_id
#
#     LEFT JOIN sys.objects  AS o2
#         ON d.referenced_id = o2.object_id
#
#     LEFT JOIN sys.synonyms AS syn_by_id
#         ON syn_by_id.object_id = d.referenced_id
#     LEFT JOIN sys.synonyms AS syn_by_name
#         ON syn_by_name.name = d.referenced_entity_name
#        AND SCHEMA_NAME(syn_by_name.schema_id) = d.referenced_schema_name
# ),
# tables_with_dependencies AS (
#     -- Tables that appear in dependencies (either as dependent or depends_on)
#     SELECT DISTINCT
#         schema_name,
#         table_name
#     FROM (
#         -- Tables that are dependents (have code)
#         SELECT
#             [Dependent_Schema] AS schema_name,
#             [Dependent_Object_Name] AS table_name
#         FROM dependency_info
#         WHERE [Dependent_Object_Type] = 'USER_TABLE'
#
#         UNION
#
#         -- Tables that are depended upon (referenced by views/SPs)
#         SELECT
#             [Depends_On_Schema] AS schema_name,
#             [Depends_On_Object_Name] AS table_name
#         FROM dependency_info
#         WHERE [Depends_On_Object_Type] = 'USER_TABLE'
#     ) AS combined
# )
#
# -- FINAL RESULT: All tables with their dependency status
# SELECT
#     t.schema_name AS [Schema],
#     t.table_name AS [Table_Name],
#     CASE
#         WHEN d.schema_name IS NULL THEN 'STATIC/ISOLATED'
#         ELSE 'HAS_DEPENDENCIES'
#     END AS [Dependency_Status],
#     CASE
#         WHEN d.schema_name IS NULL THEN 'Table not referenced in any view/SP/function and does not have triggers/constraints with dependencies'
#         ELSE 'Table is part of SQL Server dependency chain'
#     END AS [Notes]
# FROM all_tables t
# LEFT JOIN tables_with_dependencies d
#     ON t.schema_name = d.schema_name
#     AND t.table_name = d.table_name
# ORDER BY
#     [Dependency_Status] DESC,
#     t.schema_name,
#     t.table_name;
# ```

# %% [markdown]
# ## nvidia_max_performance_configs for ubuntu
# #### 1st Change to be done
# Check Current Mode:-
# ```bash
# cat /sys/devices/system/cpu/cpu*/cpufreq/scaling_governor
# ```
#
# Change Current Mode to performance:-
# ```bash
# echo performance | sudo tee /sys/devices/system/cpu/cpu*/cpufreq/scaling_governor
# ```
# Note: This resets after a reboot
#
#
# #### 2nd Change to be done(Permanent)
# 1. Stop the current Ollama server:
# ```bash
# sudo systemctl stop ollama
# ```
#
# 2. sudo systemctl edit ollama.service
# ```bash
# sudo systemctl edit ollama.service
# ```
#
# 3. In the editor that opens, add these lines in the empty space between the comments:
# ```Ini, TOML
# [Service]
# Environment="OLLAMA_FLASH_ATTENTION=1"
# ```
#
# 4. Save and exit (Ctrl+X, then Y, then Enter), then restart Ollama:
# ```bash
# sudo systemctl daemon-reload
# sudo systemctl start ollama
# ```

# %% [markdown]
# ## Create schema wise folder to store corresponding scripts

# %%
import pandas as pd
from pathlib import Path
df_definitions = pd.concat([pd.read_csv("object_definitions.csv"), pd.read_csv("UAT_object_definitions.csv")], ignore_index=True)

df_definitions = df_definitions.query("ObjectType == 'SQL_STORED_PROCEDURE'")
# # 1. Sort so that preferred database comes first
df_definitions = df_definitions.sort_values(by="DatabaseName", ascending=False)
df_definitions = df_definitions.drop_duplicates(subset=['Schema', 'Object'], keep='first')

# 1. Filter, Group, and Count
df_schema_counts = (
    df_definitions
    .query("ObjectType == 'SQL_STORED_PROCEDURE'")  # Filter data
    .groupby('Schema')                               # Group by Schema
    .size()                                          # Count rows per group
    .reset_index(name='Count')                       # Convert to DataFrame & name column
)

# 2. Sort by count (Optional, usually helpful for Excel)
df_schema_counts = df_schema_counts.sort_values(by='Count', ascending=False).reset_index()


Path("store_folders").mkdir(exist_ok=True)
for row in df_schema_counts.iloc[12:33].itertuples():
    stitched_path = f"store_folders/{row[0]}_`{row[2]}`_batch_complete_{row[3]}_fol"
    Path(stitched_path).mkdir(exist_ok = True)
    Path(f"{stitched_path}/{row[0]}_`{row[2]}`_batch_complete_{row[3]}").mkdir(exist_ok = True)
    with open(f"{stitched_path}/{row[0]}_{row[2]}_stats.json", "w", encoding='utf-8') as f:
        f.write('')

# %% [markdown]
# ## Create Sql scripts schema wise

# %%
# import pandas as pd
# from pathlib import Path
# import binascii
# import re

# # df_definitions = pd.concat([pd.read_csv("local_files/object_definitions_1.csv"), pd.read_csv("local_files/object_definitions_2.csv")], ignore_index=True)
# df_definitions = pd.read_json("_DATA_AND_OUTPUTS\local_files\object_definitions.json")

# # df_definitions = df_definitions.query("ObjectType == 'SQL_STORED_PROCEDURE'")
# df_definitions = df_definitions.query("DatabaseName == 'SPOModernization-1'")
# # # 1. Sort so that preferred database comes first
# # df_definitions = df_definitions.sort_values(by="DatabaseName", ascending=False)
# # df_definitions = df_definitions.drop_duplicates(subset=['Schema', 'Object'], keep='first')

# Path("_DATA_AND_OUTPUTS\local_files\sql_scripts_py_generated").mkdir(exist_ok=True)

# def robust_clean_sql(sql_query):
#     sql_text = str(sql_query)

#     sql_text = sql_text.replace('\\n', '\n').replace('\\t', '\t')

#     # Remove single-line comments (-- ...)
#     sql_text = re.sub(r'--.*', '', sql_text)
#     # Remove multi-line comments (/* ... */)
#     sql_text = re.sub(r'/\*.*?\*/', '', sql_text, flags=re.DOTALL)

#     # Replace multiple newlines with a single newline
#     sql_text = re.sub(r'\n\s*\n', '\n', sql_text)
#     # Collapse horizontal spaces (tabs/spaces) into one space
#     sql_text = re.sub(r'[ \t]+', ' ', sql_text)
    
#     return sql_text.strip()

# for row in df_definitions.itertuples():
#     schema_hex_suffix = binascii.hexlify(row[2].encode('utf-8')).decode('utf-8')
#     name_hex_suffix = binascii.hexlify(row[3].encode('utf-8')).decode('utf-8')
#     hex_suffix_path = f"_DATA_AND_OUTPUTS/local_files/sql_scripts_py_generated/{row[2]}---{schema_hex_suffix}"
#     print(hex_suffix_path)
#     Path(hex_suffix_path).mkdir(exist_ok=True)
#     cleaned_script = robust_clean_sql(row[5])
#     try:
#         #note:- any object name(row[3] here), containing `/` in it's name will have it replaced with below string `((forward_slash))`s
#         with open(f"{hex_suffix_path}/{row[2]}.{row[3].replace("/","((forward_slash))")}---{name_hex_suffix}.sql","w",encoding='utf-8') as f:
#             f.write(cleaned_script)
#     except Exception as e:
#         print(f"Error writing {row[2]}.{row[3]} script:\n",e)

import pandas as pd
from pathlib import Path
import binascii
import re

# df_definitions = pd.concat([pd.read_csv("local_files/object_definitions_1.csv"), pd.read_csv("local_files/object_definitions_2.csv")], ignore_index=True)
df_definitions = pd.read_json("_DATA_AND_OUTPUTS\local_files\object_definitions.json")

# df_definitions = df_definitions.query("ObjectType == 'SQL_STORED_PROCEDURE'")
# df_definitions = df_definitions.query("DatabaseName == 'SPOModernization-1'")
# # 1. Sort so that preferred database comes first
# df_definitions = df_definitions.sort_values(by="DatabaseName", ascending=False)
# df_definitions = df_definitions.drop_duplicates(subset=['Schema', 'Object'], keep='first')

Path("_DATA_AND_OUTPUTS\local_files\sql_scripts_py_generated").mkdir(exist_ok=True)

def robust_clean_sql(sql_query):
    sql_text = str(sql_query)

    sql_text = sql_text.replace('\\n', '\n').replace('\\t', '\t')

    # Remove single-line comments (-- ...)
    sql_text = re.sub(r'--.*', '', sql_text)
    # Remove multi-line comments (/* ... */)
    sql_text = re.sub(r'/\*.*?\*/', '', sql_text, flags=re.DOTALL)

    # Replace multiple newlines with a single newline
    sql_text = re.sub(r'\n\s*\n', '\n', sql_text)
    # Collapse horizontal spaces (tabs/spaces) into one space
    sql_text = re.sub(r'[ \t]+', ' ', sql_text)
    
    return sql_text.strip()

for row in df_definitions.itertuples():
    database_name = row.DatabaseName  # Extract DatabaseName from the row
    schema_hex_suffix = binascii.hexlify(row[2].encode('utf-8')).decode('utf-8')
    name_hex_suffix = binascii.hexlify(row[3].encode('utf-8')).decode('utf-8')
    hex_suffix_path = f"_DATA_AND_OUTPUTS/local_files/sql_scripts_py_generated/{database_name}/{row[2]}---{schema_hex_suffix}"
    print(hex_suffix_path)
    Path(hex_suffix_path).mkdir(parents=True, exist_ok=True)
    cleaned_script = robust_clean_sql(row[5])
    try:
        #note:- any object name(row[3] here), containing `/` in it's name will have it replaced with below string `((forward_slash))`s
        with open(f"{hex_suffix_path}/{row[2]}.{row[3].replace('/','((forward_slash))')}---{name_hex_suffix}.sql","w",encoding='utf-8') as f:
            f.write(cleaned_script)
    except Exception as e:
        print(f"Error writing {row[2]}.{row[3]} script:\n",e)

# %%
# Check total number of created files
import os
count = 0
for path in os.listdir("_DATA_AND_OUTPUTS/local_files/sql_scripts_py_generated/"):
    # print(path.split("---")[0],len(os.listdir(f"sql_scripts_py_generated/{path}")))
    count += len(os.listdir(f"_DATA_AND_OUTPUTS/local_files/sql_scripts_py_generated/{path}"))
count

# %% [markdown]
# ### Add type in all json files in a folder

# %%
import os
import json
import glob

def add_type_to_jsons(root_folder: str):
    """
    Recursively finds all JSON files in a folder and its subfolders,
    adds a "type" field at the beginning of each JSON object, and saves them.
    """
    target_field = {"type": "SQL_STORED_PROCEDURE"}
    updated_count = 0
    error_files = []

    # Create a recursive search pattern for all .json files
    # ** means it will search through all subdirectories
    search_pattern = os.path.join(root_folder, "**", "*.json")
    json_files = glob.glob(search_pattern, recursive=True)

    print(f"Found {len(json_files)} JSON files. Processing...")

    for file_path in json_files:
        try:
            # 1. Read the JSON file
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
            
            # 2. Verify the JSON root is an object (dictionary) and not an array
            if isinstance(data, dict):
                # Create a new dict with our target field first, then add the old data
                new_data = target_field.copy()
                new_data.update(data)
                
                # 3. Save the modified JSON back to the same file
                with open(file_path, 'w', encoding='utf-8') as f:
                    json.dump(new_data, f, indent=4)
                    
                updated_count += 1
            else:
                # Log an error if the JSON is a list at the root level
                error_files.append((file_path, "JSON root is an array, not an object/dictionary."))

        except json.JSONDecodeError:
            error_files.append((file_path, "Invalid JSON format (Decode Error)."))
        except Exception as e:
            error_files.append((file_path, str(e)))

    # ==========================================
    # OUTPUT RESULTS
    # ==========================================
    print("\n" + "="*40)
    print(f"✓ Total JSON files updated successfully: {updated_count}")
    
    if error_files:
        print(f"⚠️ Encountered errors in {len(error_files)} files:")
        for file_path, error_reason in error_files:
            print(f"  - {file_path} | Error: {error_reason}")
    else:
        print("✓ No errors encountered!")
    print("="*40)

# ==========================================
# EXECUTION
# ==========================================
if __name__ == "__main__":
    # Replace this with the actual path to your main folder
    FOLDER_PATH = "../lineage_output_batches" 
    
    add_type_to_jsons(FOLDER_PATH)

# %% [markdown]
# ## Add "name" property in json files, only after validating whether their parsed file name exists in excel sheet.

# %%
import os
import glob
import json
import pandas as pd
from utils import robust_clean_sql

df_definitions = pd.concat([pd.read_csv("local_files/object_definitions_1.csv"), pd.read_csv("local_files/object_definitions_2.csv")], ignore_index=True)

df_definitions = df_definitions.query("ObjectType == 'SQL_STORED_PROCEDURE'")
# # 1. Sort so that preferred database comes first
df_definitions = df_definitions.sort_values(by="DatabaseName", ascending=False)
df_definitions = df_definitions.drop_duplicates(subset=['Schema', 'Object'], keep='first')

def validate_and_update_jsons(df_definitions, root_folder):
    """
    Validates JSON files against a DataFrame and updates the valid ones
    by adding a "name" property at the beginning of the JSON object.
    """
    # 1. Fast-lookup set for validation
    valid_objects = set(zip(df_definitions['Schema'], df_definitions['Object']))
    
    updated_count = 0
    unmatched_files = []
    error_files = []
    
    # 2. Find all JSON files in the folder and subfolders
    search_pattern = os.path.join(root_folder, "**", "*.json")
    json_files = glob.glob(search_pattern, recursive=True)
    
    print(f"Found {len(json_files)} JSON files. Validating and updating...\n")
    
    for file_path in json_files:
        filename = os.path.basename(file_path)
        name_without_ext = os.path.splitext(filename)[0]
        parts = name_without_ext.split('--')
        
        # 3. Check if the file follows the index--schema--name format
        if len(parts) == 3:
            _, file_schema, file_object = parts
            
            # 4. Check if this exact combination exists in our DataFrame
            if (file_schema, file_object) in valid_objects:
                
                # --- IT'S A MATCH! Time to update the JSON ---
                try:
                    with open(file_path, 'r', encoding='utf-8') as f:
                        data = json.load(f)
                    
                    if isinstance(data, dict):
                        # Create new dict with "name" at the very beginning
                        new_data = {"name": f"{file_schema}.{file_object}"}
                        # Merge the existing data underneath it
                        new_data.update(data)
                        
                        # Save the modified JSON back to the file
                        with open(file_path, 'w', encoding='utf-8') as f:
                            json.dump(new_data, f, indent=4)
                            
                        updated_count += 1
                    else:
                        error_files.append(f"{file_path} (JSON root is an array, not a dictionary)")
                        
                except json.JSONDecodeError:
                    error_files.append(f"{file_path} (Invalid JSON format)")
                except Exception as e:
                    error_files.append(f"{file_path} (Read/Write Error: {str(e)})")
            else:
                # Combination not found in DataFrame
                unmatched_files.append(file_path)
        else:
            # File name doesn't follow the formatting rules
            error_files.append(f"{file_path} (Invalid naming format)")

    # ==========================================
    # OUTPUT RESULTS
    # ==========================================
    print("=" * 60)
    print(f"RESULTS SUMMARY")
    print("=" * 60)
    print(f"Total files scanned:        {len(json_files)}")
    print(f"✓ Files updated with 'name': {updated_count}")
    print(f"❌ Unmatched files:          {len(unmatched_files)}")
    print(f"⚠️ Error/Skipped files:      {len(error_files)}")
    
    if unmatched_files:
        print(f"\n--- Unmatched Files Sample ---")
        # Only print the first 10 so we don't flood your console if there are hundreds
        for f in unmatched_files[:10]:
            print(f"  - {f}")
        if len(unmatched_files) > 10:
            print(f"  ... and {len(unmatched_files) - 10} more.")

# ==========================================
# EXECUTION
# ==========================================
if __name__ == "__main__":
    # Assuming df_definitions is already loaded in your environment
    FOLDER_PATH = "../../lineage_output_batches"
    
    # Run the validation
    validate_and_update_jsons(df_definitions, FOLDER_PATH)
    pass

# %% [markdown]
# ##### Cross validate the "name" attribute present in json files with df_definitions which is the source of truth.

# %%
import os
import glob
import json
import re
import pandas as pd

def clean_string(text):
    """Applies your exact cleaning logic to a string."""
    return re.sub(r"[^\w\s-]", "", str(text)).strip().replace(" ", "_")

def final_validation_check(root_folder, df_definitions):
    """
    Performs a strict 3-way reconciliation between JSON filenames, 
    internal JSON 'name' attributes, and the source DataFrame.
    """
    # 1. Build a robust validation dictionary from the DataFrame
    # Maps "Actual_Schema.Actual_Object" -> Cleaned representations
    db_validation_map = {}
    for _, row in df_definitions.iterrows():
        act_schema = str(row['Schema'])
        act_obj = str(row['Object'])
        full_actual_name = f"{act_schema}.{act_obj}"
        
        db_validation_map[full_actual_name] = {
            "cleaned_schema": clean_string(act_schema),
            "cleaned_object": clean_string(act_obj)
        }

    # Tracking buckets
    passed_files = []
    err_missing_name_attr = []
    err_db_mismatch = []
    err_internal_mismatch = []
    err_bad_filename = []
    err_read_fail = []

    # 2. Grab all JSONs
    search_pattern = os.path.join(root_folder, "**", "*.json")
    json_files = glob.glob(search_pattern, recursive=True)
    
    print(f"Starting strict validation on {len(json_files)} files...\n")

    for file_path in json_files:
        filename = os.path.basename(file_path)
        name_without_ext = os.path.splitext(filename)[0]
        parts = name_without_ext.split('--')
        
        if len(parts) != 3:
            err_bad_filename.append(filename)
            continue
            
        _, file_schema, file_object = parts
        
        # 3. Open and check the JSON payload
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                
            json_name = data.get("name")
            
            if not json_name:
                err_missing_name_attr.append(filename)
                continue
                
            # 4. EXTERNAL CHECK: Does the internal name exist in the DB?
            if json_name not in db_validation_map:
                err_db_mismatch.append(f"{filename} (Payload name '{json_name}' not in DB)")
                continue
                
            # 5. INTERNAL CHECK: Does the filename match the cleaned DB name?
            expected_schema = db_validation_map[json_name]["cleaned_schema"]
            expected_object = db_validation_map[json_name]["cleaned_object"]
            
            if file_schema == expected_schema and file_object == expected_object:
                passed_files.append(filename)
            else:
                err_internal_mismatch.append(
                    f"{filename} -> Expected filename parts: '--{expected_schema}--{expected_object}'"
                )

        except Exception as e:
            err_read_fail.append(f"{filename} (Error: {str(e)})")

    # ==========================================
    # OUTPUT RESULTS
    # ==========================================
    print("=" * 60)
    print("FINAL VALIDATION REPORT")
    print("=" * 60)
    print(f"Total Files Scanned: {len(json_files)}")
    print(f"✓ PASSED (Perfect 3-Way Match): {len(passed_files)}")
    
    total_errors = len(json_files) - len(passed_files)
    if total_errors == 0:
        print("\n🎉 FLAWLESS VICTORY! All files are perfectly synchronized.")
    else:
        print(f"\n❌ FAILED VALIDATION: {total_errors} files")
        
        if err_missing_name_attr:
            print(f"\n  Missing 'name' attribute ({len(err_missing_name_attr)}):")
            for f in err_missing_name_attr: 
                print(f"   - {f}")
                
        if err_db_mismatch:
            print(f"\n  Not Found in DataFrame ({len(err_db_mismatch)}):")
            for f in err_db_mismatch: 
                print(f"   - {f}")
                
        if err_internal_mismatch:
            print(f"\n  Filename/Payload Mismatch ({len(err_internal_mismatch)}):")
            for f in err_internal_mismatch: 
                print(f"   - {f}")
            
        if err_bad_filename:
            print(f"\n  Bad Filename Format ({len(err_bad_filename)}):")
            for f in err_bad_filename: 
                print(f"   - {f}")
                
        if err_read_fail:
            print(f"\n  Read Errors ({len(err_read_fail)}):")
            for f in err_read_fail: 
                print(f"   - {f}")

# ==========================================
# EXECUTION
# ==========================================
if __name__ == "__main__":
    TARGET_FOLDER = "../../lineage_output_batches"
    final_validation_check(TARGET_FOLDER, df_definitions)
    pass
